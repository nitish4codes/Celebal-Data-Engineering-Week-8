# %% [markdown]
# # Phase 1: End-to-End Data Pipeline Demonstration
# This notebook walks through the execution of our local E-Commerce Order Analytics pipeline.

# %%
import generate_data.py
print("Generating raw dataset files...")
# This automatically executes your generation code and creates the CSVs locally
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import generate_data.py
#       2 print("Generating raw dataset files...")
#       3 # This automatically executes your generation code and creates the CSVs locally
#
# ModuleNotFoundError: No module named 'generate_data'
